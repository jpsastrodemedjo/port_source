# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = (1,2,3,4,5)
y = (2,4,6,8,10)

plt.plot(x,y,'ro--')
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
print(x[0]*y[0])
# Out:
# 2
